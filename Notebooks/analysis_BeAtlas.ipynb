# %% [markdown]
# <a href="https://colab.research.google.com/github/FredyOrjuela90/Be-star-Bayesian-Inference-Analysis/blob/main/Notebooks/analysis_BeAtlas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This code reads the 'observables_BeAtlas.inp' file and performs subsequent analyses:
# Photometry, spectroscopy, and Bayesian inference to obtain samples, based on the
# 'analysis_BeAtlas.py' code.
#
# Special thanks to Leandro Rocha Rimulo for his contribution to the 'analysis_BeAtlas.py' code.
#
# The modifications made to the original code include calculating the following statistics:
#   - maf: Mean Acceptance Fraction (global chain mixing)
#   - rhat: Gelman-Rubin statistic per parameter (consistency between walkers, ~1 => convergence)
#   - tau: Integrated Autocorrelation Time (correlation between steps; lower is better)
#   - Neff: Effective Sample Size (number of independent samples)
#
# ================================
# 1. Mount Google Drive
# ================================
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install libraries; pyhdust is used to handle simulations performed by HDUST
# https://pyhdust.readthedocs.io/
# !pip install -q numpy scipy matplotlib pyhdust
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.5/28.5 MB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 105.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 8.2 MB/s eta 0:00:00
#   Building wheel for pyhdust (setup.py) ... done

# %%
# Install emcee to generate samples using the Markov Chain Monte Carlo (MCMC) method
# and the corner library for sample visualization
# !pip install -q emcee corner
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 kB 2.7 MB/s eta 0:00:00

# %%
# ================================
# 2. PATH CONFIGURATION
#    (EDIT ONLY THESE LINES)
# ================================
import os
import glob

# Project base path in YOUR Drive:
# Replace "BeAtlas_OLD" with your actual folder name
BASE_DIR = "/content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas"   # ⬅️ AJUSTA
BASE_DIR_DOS = "/content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/OldBeAtlas"

# %%
import os
import emcee

# Check available cores (Optional for parallel processing)
n_cores = os.cpu_count()
print(f"Usando {n_cores} núcleos para paralelizar...")
# Out:
# Usando 8 núcleos para paralelizar...

# %%
# Check available cores (Optional for parallel processing)
from multiprocessing import Pool, cpu_count

n_cpu = cpu_count()
print(f"Usando {n_cpu} núcleos para paralelizar...")
# Out:
# Usando 8 núcleos para paralelizar...

# %%
# Change working directory to BASE_DIR

os.chdir(BASE_DIR)
print("Directorio actual:", os.getcwd())
# ================================
# 3. RUN ANALYSIS SCRIPT
#    Executes the main script to perform the analysis and generate results.
#    (Note: This may take some time depending on the number of walkers and steps)
# ================================


# %run analysis_BeAtlas.py


# ================================
# MCMC CONFIGURATION (operation_on_stars.inp)
# Defines the number of walkers and chains.
# "This file contains a list of procedures to be applied to
# each individual Be star with measured data."
# ================================
# Out:
# Directorio actual: /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:1178: SyntaxWarning: invalid escape sequence '\l'
#   labels = [r"$n$","$\log(\\Sigma\,[\mathrm{g\,cm^{-2}}])$",\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:1179: SyntaxWarning: invalid escape sequence '\,'
#   "$M\,[M_\odot]$","$1+0.5W^2$","$\cos i$"], bins=60)
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:1179: SyntaxWarning: invalid escape sequence '\c'
#   "$M\,[M_\odot]$","$1+0.5W^2$","$\cos i$"], bins=60)
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:1217: SyntaxWarning: invalid escape sequence '\l'
#   labels = [r"$n$","$\log(\\Sigma\,[\mathrm{g\,cm^{-2}}])$",\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:1218: SyntaxWarning: invalid escape sequence '\,'
#   "$M\,[M_\odot]$","$1+0.5W^2$","$\cos i$"], bins=60)
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:1218: SyntaxWarning: invalid escape sequence '\c'
#   "$M\,[M_\odot]$","$1+0.5W^2$","$\cos i$"], bins=60)
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:1751: SyntaxWarning: invalid escape sequence '\l'
#   labels = [r"$n$","$\log(\\Sigma\,[\mathrm{g\,cm^{-2}}])$",\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:1752: SyntaxWarning: invalid escape sequence '\,'
#   "$M\,[M_\odot]$","$1+0.5W^2$","$\cos i$",\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:1752: SyntaxWarning: invalid escape sequence '\c'
#   "$M\,[M_\odot]$","$1+0.5W^2$","$\cos i$",\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:1753: SyntaxWarning: invalid escape sequence '\l'
#   "$\log\left(\\frac{F(\\mathrm{Hu}14)}{F(\\mathrm{Pf}\gamma)}\\right)$",\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:1754: SyntaxWarning: invalid escape sequence '\l'
#   "$\log\left(\\frac{F(\\mathrm{Hu}14)}{F(\\mathrm{Br}\\alpha)}\\right)$",\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:1755: SyntaxWarning: invalid escape sequence '\l'
#   "$\\frac{F(\\mathrm{Hu}14)}{F(\lambda_B^*)}\,[\\mathrm{A}]$",\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:1756: SyntaxWarning: invalid escape sequence '\s'
#   "$v\sin i\,[\\mathrm{km/s}]$"],
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:1878: SyntaxWarning: invalid escape sequence '\l'
#   labels = [r"$n$","$\log(\\Sigma\,[\mathrm{g\,cm^{-2}}])$",\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:1879: SyntaxWarning: invalid escape sequence '\,'
#   "$M\,[M_\odot]$","$1+0.5W^2$","$\cos i$",\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:1879: SyntaxWarning: invalid escape sequence '\c'
#   "$M\,[M_\odot]$","$1+0.5W^2$","$\cos i$",\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:1880: SyntaxWarning: invalid escape sequence '\s'
#   "$v\sin i\,[\\mathrm{km/s}]$",\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:1881: SyntaxWarning: invalid escape sequence '\,'
#   "$EW\,[\\mathrm{A}]$","$PS\,[km/s]$",\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:1881: SyntaxWarning: invalid escape sequence '\,'
#   "$EW\,[\\mathrm{A}]$","$PS\,[km/s]$",\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:1882: SyntaxWarning: invalid escape sequence '\,'
#   "$I\,[\\mathrm{mag}]$","$P_V$"],
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2012: SyntaxWarning: invalid escape sequence '\,'
#   cbar.set_label("$\\tau_1^{-1}\,[2\\times 10^4\mathrm{day^{-1}}]$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2317: SyntaxWarning: invalid escape sequence '\,'
#   cbar.set_label("$\\tau_1^{-1}\,[2\\times 10^4\mathrm{day^{-1}}]$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2405: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = 0.01$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2408: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = 0.003$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2411: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = 0.001$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2414: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = 0.0003$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2417: SyntaxWarning: invalid escape sequence '\m'
#   label="r$F(\mathrm{H}_{14})/B_L = -0.0003$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2420: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = -0.001$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2423: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = -0.003$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2426: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = -0.01$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2495: SyntaxWarning: invalid escape sequence '\c'
#   auxi_annotate_vec.append("$\cos i$ = "+\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2503: SyntaxWarning: invalid escape sequence '\S'
#   figtitle.append("$n="+npar[i_n]+"$, $\Sigma_0="+sigpar[iplot1]+\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2504: SyntaxWarning: invalid escape sequence '\,'
#   "\,\mathrm{g\,cm^{-2}}$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2525: SyntaxWarning: invalid escape sequence '\S'
#   auxi_annotate_vec.append("$\Sigma_0$ = "+sigpar[iplot1])
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2533: SyntaxWarning: invalid escape sequence '\c'
#   figtitle.append("$n="+npar[i_n]+"$, $\cos i = "+\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2629: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = 0.01$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2632: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = 0.003$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2635: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = 0.001$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2638: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = 0.0003$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2641: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = -0.0003$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2644: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = -0.001$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2647: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = -0.003$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2650: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = -0.01$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2771: SyntaxWarning: invalid escape sequence '\c'
#   auxi_annotate_vec.append("$\cos i$ = "+\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2789: SyntaxWarning: invalid escape sequence '\S'
#   figtitle.append("$n="+npar[i_n]+"$, $\Sigma_0="+sigpar[iplot1]+\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2790: SyntaxWarning: invalid escape sequence '\,'
#   "\,\mathrm{g\,cm^{-2}}$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2917: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = 0.01$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2920: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = 0.003$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2923: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = 0.001$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2926: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = 0.0003$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2929: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = -0.0003$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2932: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = -0.001$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2935: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = -0.003$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:2938: SyntaxWarning: invalid escape sequence '\m'
#   label="$F(\mathrm{H}_{14})/B_L = -0.01$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:3092: SyntaxWarning: invalid escape sequence '\c'
#   auxi_annotate_vec.append("$\cos i$ = "+\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:3100: SyntaxWarning: invalid escape sequence '\S'
#   figtitle.append("$n="+npar[i_n]+"$, $\Sigma_0="+sigpar[iplot1]+\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:3101: SyntaxWarning: invalid escape sequence '\,'
#   "\,\mathrm{g\,cm^{-2}}$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:3439: SyntaxWarning: invalid escape sequence '\S'
#   labels_list = ["$n$","$\Sigma_0$","$M/M_\odot$",\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:3439: SyntaxWarning: invalid escape sequence '\o'
#   labels_list = ["$n$","$\Sigma_0$","$M/M_\odot$",\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:3440: SyntaxWarning: invalid escape sequence '\c'
#   "oblat.","$\cos i$",\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:3480: SyntaxWarning: invalid escape sequence '\m'
#   ax2.set_xlabel("K-[3.6]$\mathrm{\mu m}$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:3493: SyntaxWarning: invalid escape sequence '\m'
#   ax3.set_xlabel("[3.6]$\mathrm{\mu m}$-[5.8]$\mathrm{\mu m}$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:3507: SyntaxWarning: invalid escape sequence '\m'
#   ax4.set_ylabel("J-[3.6]$\mathrm{\mu m}$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:3519: SyntaxWarning: invalid escape sequence '\m'
#   ax5.set_xlabel("K-[3.6]$\mathrm{\mu m}$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:3520: SyntaxWarning: invalid escape sequence '\m'
#   ax5.set_ylabel("J-[3.6]$\mathrm{\mu m}$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:3532: SyntaxWarning: invalid escape sequence '\m'
#   ax6.set_xlabel("[3.6]$\mathrm{\mu m}$-[5.8]$\mathrm{\mu m}$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:3533: SyntaxWarning: invalid escape sequence '\m'
#   ax6.set_ylabel("J-[3.6]$\mathrm{\mu m}$")
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:5384: SyntaxWarning: invalid escape sequence '\l'
#   labels = ["$n$","$\log(\\Sigma\,[\mathrm{g\,cm^{-2}}])$",\
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:5385: SyntaxWarning: invalid escape sequence '\,'
#   "$M\,[M_\odot]$","$1+0.5W^2$","$\cos i$"], bins=60)
# /content/drive/MyDrive/Be-HDUST/Project_Lband_v3/Study_OldBeAtlas/analysis_BeAtlas.py:5385: SyntaxWarning: invalid escape sequence '\c'
#   "$M\,[M_\odot]$","$1+0.5W^2$","$\cos i$"], bins=60)
# /usr/local/lib/python3.12/dist-packages/pyhdust/spectools.py:63: UserWarning: wget and/or xmltodict module not installed!!!
#   _warn.warn("wget and/or xmltodict module not installed!!!")
# SAMPLING for observables alphaL and MBL of HD 191610...
# SAMPLING: DONE
# SAMPLING for observables alphaL and MBL of HD 193009...
# SAMPLING: DONE
# SAMPLING for observables alphaL and MBL of HD 194335...
# SAMPLING: DONE
# SAMPLING for observables alphaL and MBL of HD 194883...
# SAMPLING: DONE
# SAMPLING for observables alphaL and MBL of HD 217891...
# SAMPLING: DONE
# SAMPLING for observables alphaL and MBL of HD 217675...
# SAMPLING: DONE
# SAMPLING for observables alphaL and MBL of HD 210129...
# SAMPLING: DONE
# SAMPLING for observables alphaL and MBL of HD 204722...
# SAMPLING: DONE
# SAMPLING for observables alphaL and MBL of HD 202904...
# SAMPLING: DONE
# SAMPLING for observables alphaL and MBL of HD 200310...
# SAMPLING: DONE
# SAMPLING for observables alphaL and MBL of HD 197419...
# SAMPLING: DONE
# SAMPLING for observables alphaL and MBL of HD 195907...
# SAMPLING: DONE
